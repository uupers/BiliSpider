# %% [markdown]
# ## History data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

import seaborn as sns
sns.set_style("white")
fig_w = 2530
fig_h = 1900
my_dpi=200

import dateutil

# %% [markdown]
# Config plot styles

# %%
plt.style.use('ggplot')

from matplotlib import rcParams
# plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

plt.rc('font', family='BabelStone Han', size=13) # 选择你自己电脑上的字体

# %% [markdown]
# Load data

# %%
# 如果还没有数据，来群里索要数据文件就行

df = pd.read_csv('data/full-data.csv')

# %% [markdown]
# Validate all the possible columns of data frame

# %%
list(df.columns.values)
# Out:
# ['Unnamed: 0',
#  'aid',
#  'uid',
#  'time',
#  'duration',
#  'state',
#  'view',
#  'danmaku',
#  'coin',
#  'favorite',
#  'share',
#  'reply',
#  'like',
#  'sectid',
#  'sectname']

# %%
df['time'] = pd.to_datetime(df['time'],unit='s')#.dt.date

# %%
# df;

# %% [markdown]
# ## Group by sects

# %% [markdown]
# Get all the sects by sectname

# %%
sects = df.sectname.unique()
sects[0]
# Out:
# '连载剧集'

# %% [markdown]
# Create a dataframe to store the average data

# %%
index_store = ['date','tduration', 'tview', 'tcoin', 'tfavorite', 'tlike','totalv','mostaid']

# idx = 3
for idx in np.arange(len(sects) ):
    df_sect = df[df['sectname']==sects[idx]] 

    max_date = df_sect.time.max()
    min_date = df_sect.time.min()
    sect_id_str = str(df_sect.sectid.unique()[0])
    sect_name_str = str(sects[idx])
    print('Dealing with: '+sect_name_str)
    print('Start date:' + str(min_date))
    print('End date:' + str(max_date))

    dateseries = pd.date_range(start=min_date, end=max_date, freq='10D')


    df_store = pd.DataFrame(columns=index_store)


    ########
    # Loop Through Dates
    ########

    # d_idx = 0

    for d_idx in np.arange(len(dateseries) -1 ):
        df_sect_temp = df_sect[df_sect['time'].between(dateseries[d_idx],dateseries[d_idx+1])]

        if  not df_sect_temp.empty:
            mostviewed_temp = df_sect_temp.loc[df_sect_temp['view'].idxmax()].aid
            totalrows_temp = len(df_sect_temp.index)
            sumviews_temp = np.sum(df_sect_temp['view'].values)
            sumduration_temp = np.sum(df_sect_temp['duration'].values)
            sumcoin_temp = np.sum(df_sect_temp['coin'].values)
            sumfav_temp = np.sum(df_sect_temp['favorite'].values)
            sumlike_temp = np.sum(df_sect_temp['like'].values)

            df_sect_temp2 = df_sect_temp.mean().round(2)

            values_temp = [dateseries[d_idx] , sumduration_temp, sumviews_temp, sumcoin_temp, sumfav_temp, sumlike_temp, totalrows_temp ,mostviewed_temp]

            df_store_temp = pd.DataFrame([values_temp],columns=['date','tduration', 'tview', 'tcoin', 'tfavorite', 'tlike','totalv','mostaid'])


            df_store = (pd.concat([df_store, df_store_temp]) ).reset_index(drop=True)
        else:
            values_temp = [dateseries[d_idx] , 0, 0, 0, 0, 0, 0 ,0]

            df_store_temp = pd.DataFrame([values_temp],columns=['date','tduration', 'tview', 'tcoin', 'tfavorite', 'tlike','totalv','mostaid'])

            df_store = (pd.concat([df_store, df_store_temp]) ).reset_index(drop=True)

            
    print(sect_name_str + ' has ' + str( len(df_store.index) ) + 'rows' )
    
    if  not df_store.empty:
        df_store['date'] = df_store['date'].dt.date

        df_store.to_csv('export/batch/'+sect_id_str+'-'+sect_name_str+'.csv', sep=',', encoding='utf-8')

        print('Data saved')
# Out:
# Dealing with: 连载剧集
# Start date:2017-08-30 13:14:52
# End date:2017-10-24 09:16:47
# 连载剧集 has 5rows
# Data saved
# Dealing with: flash游戏
# Start date:2010-10-04 23:00:49
# End date:2012-03-30 07:24:04
# flash游戏 has 54rows
# Data saved
# Dealing with: 单机联机
# Start date:2009-07-03 11:10:16
# End date:2018-02-28 07:36:52
# 单机联机 has 316rows
# Data saved
# Dealing with: Mugen
# Start date:2009-07-14 14:59:24
# End date:2018-02-28 07:10:03
# Mugen has 315rows
# Data saved
# Dealing with: 宅舞
# Start date:2009-07-15 12:34:50
# End date:2018-02-28 07:39:39
# 宅舞 has 314rows
# Data saved
# Dealing with: 日常
# Start date:2009-06-26 07:15:45
# End date:2018-02-28 08:06:32
# 日常 has 316rows
# Data saved
# Dealing with: 鬼畜调教
# Start date:2009-07-14 01:23:55
# End date:2018-02-28 07:09:05
# 鬼畜调教 has 315rows
# Data saved
# Dealing with: MAD-AMV
# Start date:2009-07-15 07:12:48
# End date:2018-02-28 08:16:54
# MAD-AMV has 315rows
# Data saved
# Dealing with: MMD-3D
# Start date:2009-09-16 05:11:11
# End date:2018-02-28 08:24:46
# MMD-3D has 308rows
# Data saved
# Dealing with: 音MAD
# Start date:2009-07-09 07:55:49
# End date:2018-02-28 08:01:25
# 音MAD has 315rows
# Data saved
# Dealing with: 综合
# Start date:2009-07-13 11:36:05
# End date:2018-02-28 08:37:09
# 综合 has 315rows
# Data saved
# Dealing with: 原创音乐
# Start date:2010-03-18 16:03:38
# End date:2018-02-28 08:01:19
# 原创音乐 has 290rows
# Data saved
# Dealing with: 三次元音乐
# Start date:2009-07-14 10:46:02
# End date:2018-02-28 08:49:01
# 三次元音乐 has 315rows
# Data saved
# Dealing with: VOCALOID-UTAU
# Start date:2009-07-12 15:15:53
# End date:2018-02-28 08:20:34
# VOCALOID-UTAU has 315rows
# Data saved
# Dealing with: 翻唱
# Start date:2009-07-13 13:17:13
# End date:2018-02-28 09:01:31
# 翻唱 has 315rows
# Data saved
# Dealing with: 完结动画
# Start date:2009-08-26 06:57:38
# End date:2018-02-28 03:25:16
# 完结动画 has 310rows
# Data saved
# Dealing with: 连载动画
# Start date:2009-10-06 03:29:23
# End date:2018-02-28 02:12:46
# 连载动画 has 306rows
# Data saved
# Dealing with: 人文历史
# Start date:2010-10-11 05:21:01
# End date:2018-02-28 07:18:50
# 人文历史 has 269rows
# Data saved
# Dealing with: 演讲-公开课
# Start date:2010-06-17 00:21:36
# End date:2018-02-28 09:16:24
# 演讲-公开课 has 281rows
# Data saved
# Dealing with: 未知
# Start date:2015-05-11 08:43:27
# End date:2015-05-11 08:43:27
# 未知 has 0rows
# Dealing with: MMD.3D
# Start date:2011-09-01 02:19:42
# End date:2014-05-09 03:06:24
# MMD.3D has 98rows
# Data saved
# Dealing with: 短片-手书-配音
# Start date:2009-07-14 01:34:49
# End date:2018-02-28 09:21:30
# 短片-手书-配音 has 315rows
# Data saved
# Dealing with: 资讯
# Start date:2010-08-30 13:33:38
# End date:2018-02-28 13:18:07
# 资讯 has 273rows
# Data saved
# Dealing with: OP-ED-OST
# Start date:2009-09-20 09:22:24
# End date:2018-02-28 09:09:17
# OP-ED-OST has 308rows
# Data saved
# Dealing with: 演奏
# Start date:2009-07-21 03:20:03
# End date:2018-02-28 09:28:44
# 演奏 has 314rows
# Data saved
# Dealing with: 网络游戏
# Start date:2010-04-28 12:27:00
# End date:2018-02-28 10:18:47
# 网络游戏 has 286rows
# Data saved
# Dealing with: 单机游戏
# Start date:2012-06-25 14:18:48
# End date:2014-08-14 04:34:01
# 单机游戏 has 77rows
# Data saved
# Dealing with: 综艺
# Start date:2010-10-01 05:01:59
# End date:2018-02-28 10:33:32
# 综艺 has 270rows
# Data saved
# Dealing with: 动物圈
# Start date:2010-02-23 06:23:13
# End date:2018-02-28 10:44:47
# 动物圈 has 292rows
# Data saved
# Dealing with: 美食圈
# Start date:2010-03-25 04:19:33
# End date:2018-02-28 10:55:24
# 美食圈 has 289rows
# Data saved
# Dealing with: 喵星人
# Start date:2014-04-22 11:31:46
# End date:2014-04-22 11:31:46
# 喵星人 has 0rows
# Dealing with: 美食视频
# Start date:2014-04-18 14:33:01
# End date:2014-08-21 05:14:23
# 美食视频 has 12rows
# Data saved
# Dealing with: 电影相关
# Start date:2013-02-07 02:20:21
# End date:2017-10-31 15:01:36
# 电影相关 has 172rows
# Data saved
# Dealing with: 其他国家
# Start date:2016-02-22 12:41:35
# End date:2017-12-20 10:59:06
# 其他国家 has 66rows
# Data saved
# Dealing with: 短片
# Start date:2010-03-24 18:05:57
# End date:2018-02-28 11:01:11
# 短片 has 289rows
# Data saved
# Dealing with: 特摄
# Start date:2010-06-21 20:00:07
# End date:2018-02-28 10:43:29
# 特摄 has 280rows
# Data saved
# Dealing with: 剧场版
# Start date:2014-08-01 11:16:26
# End date:2015-03-17 14:01:30
# 剧场版 has 22rows
# Data saved
# Dealing with: 数码
# Start date:2010-07-22 15:58:01
# End date:2018-02-28 11:16:49
# 数码 has 277rows
# Data saved
# Dealing with: 星海
# Start date:2011-03-22 17:55:22
# End date:2018-02-28 11:21:27
# 星海 has 253rows
# Data saved
# Dealing with: 机械
# Start date:2010-02-14 19:57:33
# End date:2018-02-28 11:25:32
# 机械 has 293rows
# Data saved
# Dealing with: GMV
# Start date:2010-07-26 14:57:28
# End date:2018-02-28 11:26:16
# GMV has 277rows
# Data saved
# Dealing with: 野生技术协会
# Start date:2009-09-09 01:09:09
# End date:2018-02-28 11:38:47
# 野生技术协会 has 309rows
# Data saved
# Dealing with: 趣味科普人文
# Start date:2009-10-14 04:38:56
# End date:2018-02-28 11:49:46
# 趣味科普人文 has 305rows
# Data saved
# Dealing with: 其他
# Start date:2009-09-13 07:01:43
# End date:2018-02-28 14:17:25
# 其他 has 309rows
# Data saved
# Dealing with: 人力VOCALOID
# Start date:2009-11-20 03:59:58
# End date:2018-02-28 11:53:18
# 人力VOCALOID has 302rows
# Data saved
# Dealing with: 教程演示
# Start date:2010-03-02 03:33:45
# End date:2018-02-27 15:43:02
# 教程演示 has 291rows
# Data saved
# Dealing with: 电视剧相关
# Start date:2012-10-14 10:14:57
# End date:2017-10-31 22:39:57
# 电视剧相关 has 184rows
# Data saved
# Dealing with: 音乐选集
# Start date:2009-07-09 06:07:51
# End date:2018-02-28 12:15:05
# 音乐选集 has 315rows
# Data saved
# Dealing with: Korea相关
# Start date:2011-08-11 04:16:29
# End date:2018-02-28 12:28:16
# Korea相关 has 239rows
# Data saved
# Dealing with: 音游
# Start date:2009-07-21 14:14:31
# End date:2018-02-28 12:21:43
# 音游 has 314rows
# Data saved
# Dealing with: 明星
# Start date:2012-06-10 10:56:41
# End date:2018-02-28 12:45:54
# 明星 has 208rows
# Data saved
# Dealing with: 搞笑
# Start date:2010-02-09 09:37:26
# End date:2018-02-28 12:50:05
# 搞笑 has 294rows
# Data saved
# Dealing with: 实况解说
# Start date:2015-04-08 17:53:37
# End date:2015-04-09 01:19:13
# 实况解说 has 0rows
# Dealing with: 游戏集锦
# Start date:2015-04-08 23:17:14
# End date:2015-04-08 23:42:10
# 游戏集锦 has 0rows
# Dealing with: 欧美电影
# Start date:2016-02-22 11:45:41
# End date:2018-02-12 15:55:51
# 欧美电影 has 72rows
# Data saved
# Dealing with: 日本电影
# Start date:2016-05-11 06:11:29
# End date:2018-01-26 08:49:37
# 日本电影 has 62rows
# Data saved
# Dealing with: 国产电影
# Start date:2012-01-03 08:49:05
# End date:2018-02-28 02:34:13
# 国产电影 has 224rows
# Data saved
# Dealing with: 官方延伸
# Start date:2010-01-07 03:46:26
# End date:2018-02-28 11:37:35
# 官方延伸 has 297rows
# Data saved
# Dealing with: 国产动画
# Start date:2010-01-23 22:47:56
# End date:2018-02-28 03:30:00
# 国产动画 has 295rows
# Data saved
# Dealing with: 三次元舞蹈
# Start date:2010-09-08 21:56:54
# End date:2018-02-28 12:40:54
# 三次元舞蹈 has 272rows
# Data saved
# Dealing with: 舞蹈教程
# Start date:2011-04-02 11:17:02
# End date:2018-02-28 04:07:41
# 舞蹈教程 has 252rows
# Data saved
# Dealing with: 美妆
# Start date:2014-04-21 18:15:57
# End date:2018-02-28 13:06:05
# 美妆 has 140rows
# Data saved
# Dealing with: 服饰
# Start date:2013-11-24 12:11:47
# End date:2018-02-28 13:00:58
# 服饰 has 155rows
# Data saved
# Dealing with: 手工
# Start date:2010-09-29 17:44:14
# End date:2018-02-28 13:11:51
# 手工 has 270rows
# Data saved
# Dealing with: 绘画
# Start date:2010-03-17 00:33:51
# End date:2018-02-28 12:54:55
# 绘画 has 290rows
# Data saved
# Dealing with: 运动
# Start date:2010-07-24 08:31:15
# End date:2018-02-28 13:19:40
# 运动 has 277rows
# Data saved
# Dealing with: 健身
# Start date:2014-07-28 13:04:28
# End date:2018-02-28 13:00:58
# 健身 has 131rows
# Data saved
# Dealing with: 广告
# Start date:2009-07-13 18:34:45
# End date:2018-02-28 13:20:06
# 广告 has 315rows
# Data saved
# Dealing with: 国产原创相关
# Start date:2009-09-30 12:42:21
# End date:2018-02-28 13:19:43
# 国产原创相关 has 307rows
# Data saved
# Dealing with: 布袋戏
# Start date:2010-02-14 11:05:42
# End date:2018-02-28 09:27:27
# 布袋戏 has 293rows
# Data saved
# Dealing with: 电子竞技
# Start date:2009-07-09 19:15:16
# End date:2018-02-28 13:49:44
# 电子竞技 has 315rows
# Data saved
# Dealing with: 手机游戏
# Start date:2010-02-06 19:12:21
# End date:2018-02-28 14:08:13
# 手机游戏 has 294rows
# Data saved
# Dealing with: 桌游棋牌
# Start date:2010-03-27 14:17:19
# End date:2018-02-28 14:07:32
# 桌游棋牌 has 289rows
# Data saved
# Dealing with: ASMR
# Start date:2010-05-29 03:11:51
# End date:2018-02-28 14:22:05
# ASMR has 283rows
# Data saved
# Dealing with: 汽车
# Start date:2011-01-12 13:41:51
# End date:2018-02-28 14:19:35
# 汽车 has 260rows
# Data saved
# Dealing with: 科学探索
# Start date:2010-06-03 09:55:15
# End date:2018-02-28 10:01:16
# 科学探索 has 282rows
# Data saved
# Dealing with: 热血军事
# Start date:2010-12-23 06:50:28
# End date:2018-02-28 06:08:24
# 热血军事 has 262rows
# Data saved
# Dealing with: 舌尖上的旅行
# Start date:2011-06-08 23:18:17
# End date:2018-02-28 10:58:27
# 舌尖上的旅行 has 245rows
# Data saved
# Dealing with: 影视杂谈
# Start date:2011-07-08 04:36:59
# End date:2018-02-28 14:28:54
# 影视杂谈 has 242rows
# Data saved
# Dealing with: 影视剪辑
# Start date:2010-02-03 14:12:18
# End date:2018-02-28 15:00:27
# 影视剪辑 has 294rows
# Data saved
# Dealing with: 预告 资讯
# Start date:2009-06-26 07:11:36
# End date:2018-02-28 14:45:07
# 预告 资讯 has 316rows
# Data saved
# Dealing with: 国产剧
# Start date:2011-02-04 11:04:49
# End date:2018-02-28 08:04:43
# 国产剧 has 258rows
# Data saved
# Dealing with: 海外剧
# Start date:2014-08-09 05:55:52
# End date:2018-02-25 02:00:00
# 海外剧 has 129rows
# Data saved
